# %%
# %cd /content/drive/MyDrive/deep_learning_tireoide

# !wget https://download.wetransfer.com/eugv/21d5d94a9ad30bacb6d104ae1d2e45a020210722101610/e30d8d51e54324969071e9099626b8c3225dd7d1/Prof%20Helton%20Ramos.zip?token=eyJhbGciOiJIUzI1NiJ9.....PpCp07O3jfxILZLzBAV5yDzM8XJDyx5RruTUOJJVWEo&cf=y
# Out:
# /content/drive/MyDrive/deep_learning_tireoide
# The name is too long, 1019 chars total.
# Trying to shorten...
# New name is Prof Helton Ramos.zip?token=eyJhbGciOiJIUzI1NiJ9.eyJpYXQiOjE2MjY5NjQwNzAsImV4cCI6MTYyNjk2NDY3MCwidW5pcXVlIjoiMjFkNWQ5NGE5YWQzMGJhY2I2ZDEwNGFlMWQyZTQ1YTAyMDIxMDcyMjEwMTYxMCIsImZpbGVuYW1lIjoiUHJvZiBIZWx0b24gUmFtb3MuemlwIiwid2F5YmlsbF91cmw.
# --2021-07-22 14:28:04--  https://download.wetransfer.com/eugv/21d5d94a9ad30bacb6d104ae1d2e45a020210722101610/e30d8d51e54324969071e9099626b8c3225dd7d1/Prof%20Helton%20Ramos.zip?token=eyJhbGciOiJIUzI1NiJ9.....PpCp07O3jfxILZLzBAV5yDzM8XJDyx5RruTUOJJVWEo
# Resolving download.wetransfer.com (download.wetransfer.com)... 13.35.89.16, 13.35.89.102, 13.35.89.9, ...
# Connecting to download.wetransfer.com (download.wetransfer.com)|13.35.89.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19692031209 (18G) [binary/octet-stream]
# ...

# %%
# %ls
# Out:
#  0224-3.svs                         download-tireoide.ipynb
#  arquivos-scanners-tireoide.ipynb  'Prof Helton Ramos.zip'

# %%
import zipfile

# %%
with zipfile.ZipFile("arquivos-tireoide.zip", 'r') as zip_ref:
    zip_ref.extractall("./arquivos-tireoide")

# %%
# %cd /content/drive/MyDrive/deep_learning_tireoide/

# !wget https://groovy.jfrog.io/ui/api/v1/download?repoKey=dist-release-local&path=groovy-windows-installer%252Fgroovy-4.0.0-alpha-3%252Fgroovy-4.0.0-alpha-3.msi
# Out:
# /content/drive/MyDrive/deep_learning_tireoide
# --2021-07-24 23:44:16--  https://groovy.jfrog.io/ui/api/v1/download?repoKey=dist-release-local
# Resolving groovy.jfrog.io (groovy.jfrog.io)... 35.224.162.219
# Connecting to groovy.jfrog.io (groovy.jfrog.io)|35.224.162.219|:443... connected.
# HTTP request sent, awaiting response... 500 Internal Server Error
# 2021-07-24 23:44:16 ERROR 500: Internal Server Error.
